# %%
import pandas as pd

# %%
df_pop = pd.read_csv("data/racial-profile-elementary-school.csv")
df_pop
# Out:
#                        Location           Elementary Schools  TimeFrame  \
# 0          Battery Park/Tribeca                      Diverse       2019
# 1             Greenwich Village                      Diverse       2019
# 2               Lower East Side                      Diverse       2019
# 3               Chelsea/Clinton                      Diverse       2019
# 4     Midtown Business District                      Diverse       2019
# ...                         ...                          ...        ...
# 4069                   Brooklyn  Predominantly White + Asian       2021
# 4070                  Manhattan  Predominantly White + Asian       2021
# 4071                     Queens  Predominantly White + Asian       2021
# 4072              Staten Island  Predominantly White + Asian       2021
# 4073              New York City  Predominantly White + Asian       2021
#
#      DataFormat     Data     Fips
# 0        Number  1.00000      101
# ...

# %%
df_race = pd.read_csv("data/RAW_Student Racial_Ethnic Diversity.csv")
df_race
# Out:
#                        Location                        Total  TimeFrame  \
# 0          Battery Park/Tribeca                      Diverse       2019
# 1             Greenwich Village                      Diverse       2019
# 2               Lower East Side                      Diverse       2019
# 3               Chelsea/Clinton                      Diverse       2019
# 4     Midtown Business District                      Diverse       2019
# ...                         ...                          ...        ...
# 4069                   Brooklyn  Predominantly White + Asian       2021
# 4070                  Manhattan  Predominantly White + Asian       2021
# 4071                     Queens  Predominantly White + Asian       2021
# 4072              Staten Island  Predominantly White + Asian       2021
# 4073              New York City  Predominantly White + Asian       2021
#
#      DataFormat      Data     Fips
# 0        Number   8.00000      101
# ...

# %%
df_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4074 entries, 0 to 4073
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    4074 non-null   object
#  1   Total       4074 non-null   object
#  2   TimeFrame   4074 non-null   int64
#  3   DataFormat  4074 non-null   object
#  4   Data        4074 non-null   float64
#  5   Fips        4074 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 191.1+ KB

# %%
df_race["Location"].value_counts()
# Out:
# East New York          84
# Upper West Side        84
# Mott Haven             84
# Washington Heights     84
# East Harlem            84
#                        ..
# Bensonhurst            42
# Bay Ridge              42
# Crown Heights South    42
# Crown Heights North    42
# New York City          42
# Name: Location, Length: 87, dtype: int64

# %%
df_race["TimeFrame"].max()
# Out:
# 2021

# %%
df_rqueens = df_race[df_race['Location'].eq("Queens")]
df_rqueens
# Out:
#      Location                           Total  TimeFrame DataFormat  \
# 94     Queens                         Diverse       2019     Number
# 191    Queens                         Diverse       2020     Number
# 288    Queens                         Diverse       2019    Percent
# 385    Queens                         Diverse       2020    Percent
# 482    Queens             Predominantly Asian       2019     Number
# 579    Queens             Predominantly Asian       2020     Number
# 676    Queens             Predominantly Asian       2019    Percent
# 773    Queens             Predominantly Asian       2020    Percent
# 870    Queens             Predominantly Black       2019     Number
# 967    Queens             Predominantly Black       2020     Number
# 1064   Queens             Predominantly Black       2019    Percent
# 1161   Queens             Predominantly Black       2020    Percent
# 1258   Queens  Predominantly Black + Hispanic       2019     Number
# ...
